# %%
import pandas as pd
import sqlalchemy
import pprint
import psycopg2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sqlalchemy import create_engine

# %%
# connect to local database
# https://docs.sqlalchemy.org/en/14/core/engines.html#postgresql
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/sql_challenge')
connection = engine.connect()

# %%
# Test connection on first table in ERD
departments = pd.read_sql('SELECT * FROM departments', connection)
departments
# Out:
#   dept_no           dept_name
# 0    d001           Marketing
# 1    d002             Finance
# 2    d003     Human Resources
# 3    d004          Production
# 4    d005         Development
# 5    d006  Quality Management
# 6    d007               Sales
# 7    d008            Research
# 8    d009    Customer Service

# %%
# Create a histogram to visualize the most common salary ranges for employees.
# Based on ERD, should only require salaries table
salaries = pd.read_sql('SELECT * FROM salaries', connection)
salaries
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axvline.html
def histogram():
    plt.figure(figsize = (10,6))
    plt.axvline(salaries['salary'].mean(), color='k', linestyle='dashed', linewidth=1, label="Salary Mean")
    plt.xlabel("Salary", fontsize = 12)
    plt.ylabel("Number of Employees", fontsize = 12)
    plt.legend(loc = 0)
    plt.grid(zorder = 0)
    plt.title("Common Salary Ranges", fontweight = 'bold', fontsize = 12)
    plt.hist(salaries['salary'], 20, density=False, label="Salary")
    plt.savefig("Common Salary Ranges.png")

# %%
histogram()
print(f"The most common salary appears to be $40k. The mean salary in the data is ${'${:0,.0f}'.format(salaries['salary'].mean())}.\
\nHowever, one of the limitations of the data is that the employees dataset only considers their hire date.\
\nIt is possible (and could be confirmed through further analysis) that the bulk of the $40k salaried employees\
\nwere hired at an earlier time, and that the salary graduation towards $100k is a result of income growth over time.")
# Out:
# The most common salary appears to be $40k. The mean salary in the data is $$52,971.
# However, one of the limitations of the data is that the employees dataset only considers their hire date.
# It is possible (and could be confirmed through further analysis) that the bulk of the $40k salaried employees
# were hired at an earlier time, and that the salary graduation towards $100k is a result of income growth over time.

# %%
# Create a bar chart of average salary by title.
# import titles and employees as df to merge
titles = pd.read_sql('SELECT * FROM titles', connection)
employees = pd.read_sql('SELECT * FROM employees', connection)

# %%
titles
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
employees.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001  1953-07-25    Hideyuki   Zallocco   M  1990-04-28
# 1  475053        e0002  1954-11-18       Byong  Delgrande   F  1991-09-07
# 2   57444        e0002  1958-01-30       Berry       Babb   F  1992-03-21
# 3  421786        s0001  1957-09-28       Xiong   Verhoeff   M  1987-11-26
# 4  282238        e0003  1952-10-28  Abdelkader    Baumann   F  1991-01-18

# %%
merge_1 = employees.merge(titles, how = 'inner', left_on = 'emp_title_id', right_on = 'title_id')
merge_1.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name   last_name sex   hire_date  \
# 0  473302        s0001  1953-07-25    Hideyuki    Zallocco   M  1990-04-28
# 1  421786        s0001  1957-09-28       Xiong    Verhoeff   M  1987-11-26
# 2  273487        s0001  1957-04-14   Christoph     Parfitt   M  1991-06-28
# 3  246449        s0001  1958-03-23       Subbu  Bultermann   F  1988-03-25
# 4   48085        s0001  1964-01-19  Venkatesan        Gilg   M  1993-06-28
#
#   title_id  title
# 0    s0001  Staff
# 1    s0001  Staff
# 2    s0001  Staff
# 3    s0001  Staff
# 4    s0001  Staff

# %%
merge_2 = pd.merge(merge_1, salaries, on = 'emp_no')
merge_2.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name   last_name sex   hire_date  \
# 0  473302        s0001  1953-07-25    Hideyuki    Zallocco   M  1990-04-28
# 1  421786        s0001  1957-09-28       Xiong    Verhoeff   M  1987-11-26
# 2  273487        s0001  1957-04-14   Christoph     Parfitt   M  1991-06-28
# 3  246449        s0001  1958-03-23       Subbu  Bultermann   F  1988-03-25
# 4   48085        s0001  1964-01-19  Venkatesan        Gilg   M  1993-06-28
#
#   title_id  title  salary
# 0    s0001  Staff   40000
# 1    s0001  Staff   40000
# 2    s0001  Staff   56087
# 3    s0001  Staff   87084
# 4    s0001  Staff   63016

# %%
title_salary = merge_2[["title","salary"]]
avg_salary_title = title_salary.groupby('title').mean().reset_index()
avg_salary_title
# Out:
#                 title        salary
# 0  Assistant Engineer  48564.434447
# 1            Engineer  48535.336511
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.799871
# 4        Senior Staff  58550.172704
# 5               Staff  58465.382850
# 6    Technique Leader  48582.896092

# %%
def bar():
    plt.figure(figsize = (10,6))
    plt.xlabel("Position Title", fontsize = 12)
    plt.ylabel("Average Salary", fontsize = 12)
    plt.grid(zorder = 0)
    plt.title("Average Salaries by Position Title", fontweight = 'bold', fontsize = 12)
    plt.bar(avg_salary_title['title'], avg_salary_title['salary'], zorder = 3)
    plt.savefig("Average Salaries by Position Title.png")

# %%
bar()
print(f"This plot shows the average salaries per position title. It would appear that Senior Staff and Staff positions\
\npaid the most on average, with Senior Engineers paid the least.")
# Out:
# This plot shows the average salaries per position title. It would appear that Senior Staff and Staff positions
# paid the most on average, with Senior Engineers paid the least.

# %%
# "Search your ID number." - 499942
myself = pd.read_sql('SELECT emp_no, first_name, last_name FROM employees WHERE emp_no = 499942', connection)
myself
# Out:
#    emp_no first_name last_name
# 0  499942      April  Foolsday

# %%
print(f"Unfortunately it isn't April ... could've fooled me.")
# Out:
# Unfortunately it isn't April ... could've fooled me.
